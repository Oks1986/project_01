# %%
import random
my_favorite_songs = [
    "'Waste a Moment', 3.03",
    "'New Salvation', 4.02",
    "'Staying\\' Alive', 3.40",
    "'Out of Touch', 3.03",
    "'A Sorta Fairytale', 5.28",
    "'Easy', 4.15",
    "'Beautiful Day', 4.04",
    "'Nowhere to Run', 2.58",
    "'In This World', 4.02"]
a=random.choice(my_favorite_songs)
b=random.choice(my_favorite_songs)
c=random.choice(my_favorite_songs)
print(a,b,c)
# Out:
# 'Staying\' Alive', 3.40 'Beautiful Day', 4.04 'New Salvation', 4.02

# %%
import re
re.findall(r'[\d]*[.][\d]+'  , "Waste a Moment 3.03 New Salvation 4.02 Staying\' Alive 3.40 Out of Touch 3.03 A Sorta Fairytale 5.28 Easy 4.15 Beautiful Day 4.04 Nowhere to Run 2.58 In This World 4.02")
# Out:
# ['3.03', '4.02', '3.40', '3.03', '5.28', '4.15', '4.04', '2.58', '4.02']

# %%
line = "Waste a Moment 3.03 New Salvation 4.02 Staying\' Alive 3.40 Out of Touch 3.03 A Sorta Fairytale 5.28 Easy 4.15 Beautiful Day 4.04 Nowhere to Run 2.58 In This World 4.02"
import re
h =re.findall('\d+', line)
print(h)
# Out:
# ['3', '03', '4', '02', '3', '40', '3', '03', '5', '28', '4', '15', '4', '04', '2', '58', '4', '02']
