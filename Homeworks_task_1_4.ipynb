# %%
titles = {
    'Кроссовки тип 3 (Adidas)': '100000110',
    'Мячик тип 2 (Adidas)': '100000146',
    'Кепка тип 1 (Adidas)': '100000149',
    'Ремень тип 2 (Nike)': '100000194',
    'Футболка тип 1 (Adidas)': '100000224',
    'Шапка тип 5 (Puma)': '100000280',
}
store = {
    '100000110': [{'quantity': 31, 'price': 1637}],
    '100000146': [ {'quantity': 4, 'price': 45}, {'quantity': 10, 'price': 48}],
    '100000149': [ {'quantity': 28, 'price': 279}, {'quantity': 32, 'price': 291}],
    '100000194': [{'quantity': 8, 'price': 220}, {'quantity': 1, 'price': 170}],
    '100000224': [{'quantity': 61, 'price': 438}, {'quantity': 23, 'price': 302},  {'quantity': 50, 'price': 412}],
    '100000280': [{'quantity': 26, 'price': 175}, ]
}
for i in titles: 
    s = 0 
    k = 0
    # titles[i] - по названию товара получаю его код 
    # store[titles[i]] - по коду товара получаю список закупок 
    # В переменной j - словарь с количеством и ценой 
    for j in store[titles[i]]: 
        # Вычисляю сумму поступления как умножение количества товара 
        # на стоимость за единицу 
        s += j["quantity"] * j["price"] 
        k += j['quantity']
    # Для товара i вывожу на какую он сумму на складе 
    print( i , "-", k,"шт., стоимость", s)
# Out:
# Кроссовки тип 3 (Adidas) - 31 шт., стоимость 50747
# Мячик тип 2 (Adidas) - 14 шт., стоимость 660
# Кепка тип 1 (Adidas) - 60 шт., стоимость 17124
# Ремень тип 2 (Nike) - 9 шт., стоимость 1930
# Футболка тип 1 (Adidas) - 134 шт., стоимость 54264
# Шапка тип 5 (Puma) - 26 шт., стоимость 4550
