# %%
a = [4,6,2,1,9,63,-134,566]
print (a)
min = a[0]
for i in a:
  if i < min:
    min = i
print (min, 'Минимум')
max = a[0]
for i in a:
  if i > max:
    max = i
print (max, 'Максимум')
# Out:
# [4, 6, 2, 1, 9, 63, -134, 566]
# -134 Минимум
# 566 Максимум
